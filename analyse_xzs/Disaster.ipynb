# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

# %%
disaster = pd.read_csv('/Users/wowblk/Desktop/数据集/全球自然灾害数据/Disaster.csv')
disaster
# Out:
#              Dis No  Year   Seq           Glide Disaster Group  \
# 0     2000-0372-CHN  2000   372             NaN        Natural
# 1     2000-9186-AFG  2000  9186             NaN        Natural
# 2     2000-0373-BGD  2000   373             NaN        Natural
# 3     2000-0905-BOL  2000   905             NaN        Natural
# 4     2000-0019-BRA  2000    19             NaN        Natural
# ...             ...   ...   ...             ...            ...
# 9416  2022-0255-COD  2022   255  EP-2022-000202        Natural
# 9417  2022-0263-COD  2022   263  EP-2022-000205        Natural
# 9418  2022-0569-ZWE  2022   569  EP-2022-000304        Natural
# 9419  2022-0201-TLS  2022   201  EP-2022-000162        Natural
# 9420  2022-0650-SSD  2022   650             NaN        Natural
#
#      Disaster Subgroup Disaster Type Disaster Subtype Disaster Subsubtype  \
# 0         Hydrological         Flood   Riverine flood                 NaN
# ...

# %%
print(disaster['Disaster Group'].value_counts().sum())
# Out:
# 9421

# %%
print(disaster['Disaster Subgroup'].value_counts())
# Out:
# Hydrological         4242
# Meteorological       2834
# Biological            917
# Geophysical           756
# Climatological        664
# Complex Disasters       7
# Extra-terrestrial       1
# Name: Disaster Subgroup, dtype: int64

# %%
print(disaster['Disaster Type'].value_counts())
# Out:
# Flood                    3824
# Storm                    2389
# Epidemic                  887
# Earthquake                623
# Extreme temperature       445
# Landslide                 418
# Drought                   380
# Wildfire                  281
# Volcanic activity         120
# Insect infestation         29
# Mass movement (dry)        13
# Complex Disasters           7
# Glacial lake outburst       3
# Impact                      1
# Animal accident             1
# Name: Disaster Type, dtype: int64

# %%
print(disaster['Disaster Subtype'].value_counts())
# Out:
# Riverine flood                      2023
# Tropical cyclone                    1237
# Convective storm                     800
# Flash flood                          658
# Ground movement                      593
# Bacterial disease                    411
# Viral disease                        379
# Drought                              379
# Landslide                            320
# Cold wave                            218
# Forest fire                          188
# Heat wave                            154
# Extra-tropical storm                 127
# Ash fall                              98
# Severe winter conditions              73
# Avalanche                             48
# Land fire (Brush, Bush, Pasture)      46
# Coastal flood                         41
# Mudslide                              41
# Tsunami                               30
# Locust                                26
# Parasitic disease                     17
# Lava flow                              9
# ...

# %%
print(disaster['Disaster Subsubtype'].value_counts())
# Out:
# Winter storm/Blizzard      171
# Severe storm               171
# Lightning/Thunderstorms    166
# Tornado                    155
# Hail                        46
# Sand/Dust storm             12
# Storm/Surge                  7
# Snow/Ice                     6
# Derecho                      6
# Sudden subsidence            1
# Rain                         1
# Name: Disaster Subsubtype, dtype: int64

# %%
print(disaster[disaster['Disaster Subgroup'] =='Meteorological']['Disaster Type'].value_counts())
print('\n')
print(disaster[disaster['Disaster Subgroup'] =='Meteorological']['Disaster Subtype'].value_counts())
print('\n')
print(disaster[disaster['Disaster Subgroup'] =='Meteorological']['Disaster Subsubtype'].value_counts())
# Out:
# Storm                  2389
# Extreme temperature     445
# Name: Disaster Type, dtype: int64
#
#
# Tropical cyclone            1237
# Convective storm             800
# Cold wave                    218
# Heat wave                    154
# Extra-tropical storm         127
# Severe winter conditions      73
# Name: Disaster Subtype, dtype: int64
#
#
# Severe storm               171
# Winter storm/Blizzard      170
# Lightning/Thunderstorms    166
# Tornado                    155
# Hail                        46
# Sand/Dust storm             12
# Storm/Surge                  7
# Snow/Ice                     6
# Derecho                      6
# Rain                         1
# Name: Disaster Subsubtype, dtype: int64

# %%
print(disaster[disaster['Disaster Subgroup'] =='Climatological']['Disaster Type'].value_counts())
print('\n')
print(disaster[disaster['Disaster Subgroup'] =='Climatological']['Disaster Subtype'].value_counts())
print('\n')
print(disaster[disaster['Disaster Subgroup'] =='Climatological']['Disaster Subsubtype'].value_counts())
# Out:
# Drought                  380
# Wildfire                 281
# Glacial lake outburst      3
# Name: Disaster Type, dtype: int64
#
#
# Drought                             379
# Forest fire                         188
# Land fire (Brush, Bush, Pasture)     46
# Name: Disaster Subtype, dtype: int64
#
#
# Series([], Name: Disaster Subsubtype, dtype: int64)

# %%
print(disaster[disaster['Disaster Subgroup'] =='Climatological']['Disaster Subsubtype'].sum())
# Out:
# 0

# %%
labels = ['Hydrological','Meteorological','Biological','Geophysical','Climatological']
data1 = disaster[disaster['Disaster Subgroup'] == 'Hydrological']['Disaster Type'].value_counts().sum()
data2 = disaster[disaster['Disaster Subgroup'] == 'Meteorological']['Disaster Type'].value_counts().sum()
data3 = disaster[disaster['Disaster Subgroup'] == 'Biological']['Disaster Type'].value_counts().sum()
data4 = disaster[disaster['Disaster Subgroup'] == 'Geophysical']['Disaster Type'].value_counts().sum()
data5 = disaster[disaster['Disaster Subgroup'] == 'Climatological']['Disaster Type'].value_counts().sum()
data6 = disaster[disaster['Disaster Subgroup'] == 'Complex Disasters']['Disaster Type'].value_counts().sum()
data7 = disaster[disaster['Disaster Subgroup'] == 'Extra-terrestrial']['Disaster Type'].value_counts().sum()

data = [data1,data2,data3,data4,data5]

fig, ax = plt.subplots()
explode = (0, 0.1, 0, 0, 0.1)
ax.pie(data,labels=None, autopct='%1.1f%%', startangle=80, pctdistance=0.85,wedgeprops={'linewidth': 2})
centre_circle = plt.Circle((0,0), 0.70, fc='white')
ax.axis('equal')
plt.title('Disaster', fontsize=14)
ax.legend(labels, loc='upper left', bbox_to_anchor=(0.8, 1), prop={'family': 'serif', 'size': 10, 'weight': 'bold'},edgecolor='black', frameon=True)
plt.show()

# %%
labels = ['Hydrological', 'Meteorological', 'Biological', 'Geophysical', 'Climatological']
data1 = disaster[disaster['Disaster Subgroup'] == 'Hydrological']['Disaster Type'].value_counts().sum()
data2 = disaster[disaster['Disaster Subgroup'] == 'Meteorological']['Disaster Type'].value_counts().sum()
data3 = disaster[disaster['Disaster Subgroup'] == 'Biological']['Disaster Type'].value_counts().sum()
data4 = disaster[disaster['Disaster Subgroup'] == 'Geophysical']['Disaster Type'].value_counts().sum()
data5 = disaster[disaster['Disaster Subgroup'] == 'Climatological']['Disaster Type'].value_counts().sum()

data = [data1, data2, data3, data4, data5]

fig, ax = plt.subplots(figsize=(8, 6))
explode = (0, 0.1, 0, 0, 0.1)
colors = ['#007acc', '#00ba00', '#ff7f0e', '#ab003c', '#ffa500']

wedges, texts, autotexts = ax.pie(data, labels=None, startangle=80, pctdistance=0.85,
                                  wedgeprops={'linewidth': 2, 'edgecolor': 'white', 'linestyle': 'solid'},
                                  autopct='%1.1f%%', textprops={'fontsize': 12}, colors=colors,
                                  explode=explode, labeldistance=None, shadow=True)

plt.setp(autotexts, size=12, weight='bold', color='white', fontfamily='serif')



plt.title('Disaster', fontsize=18, fontweight='bold', fontfamily='serif', y=1.1)

# Set legend properties
legend_properties = {'family': 'serif', 'size': 14, 'weight': 'bold', 'style': 'italic', 'edgecolor': 'black', 'facecolor': 'white'}

# 设置图例
ax.legend(labels, loc='upper left', bbox_to_anchor=(0.9, 1),
          prop={'family': 'serif', 'size': 12, 'weight': 'bold'},
          edgecolor='black', frameon=True)

plt.tight_layout()
plt.show()

# %%
filter_disaster = disaster.loc[(disaster['Disaster Subgroup'] =='Meteorological') | (disaster['Disaster Subgroup'] == 'Climatological')]
filter_disaster
# Out:
#              Dis No  Year   Seq Glide Disaster Group Disaster Subgroup  \
# 1     2000-9186-AFG  2000  9186   NaN        Natural    Climatological
# 9     2000-0311-AUT  2000   311   NaN        Natural    Meteorological
# 11    2000-9495-ARM  2000  9495   NaN        Natural    Climatological
# 12    2000-9537-BIH  2000  9537   NaN        Natural    Climatological
# 13    2000-0097-AUS  2000    97   NaN        Natural    Meteorological
# ...             ...   ...   ...   ...            ...               ...
# 9399  2022-9209-USA  2022  9209   NaN        Natural    Climatological
# 9400  2022-0215-USA  2022   215   NaN        Natural    Climatological
# 9401  2022-0246-USA  2022   246   NaN        Natural    Climatological
# 9403  2022-0454-USA  2022   454   NaN        Natural    Climatological
# 9415  2022-0209-COD  2022   209   NaN        Natural    Meteorological
#
#      Disaster Type  Disaster Subtype Disaster Subsubtype  \
# ...

# %%
disaster_2000 = filter_disaster.loc[(filter_disaster['Year'] == 2000)]
disaster_2001 = filter_disaster.loc[(filter_disaster['Year'] == 2001)]
disaster_2002 = filter_disaster.loc[(filter_disaster['Year'] == 2002)]
disaster_2003 = filter_disaster.loc[(filter_disaster['Year'] == 2003)]
disaster_2004 = filter_disaster.loc[(filter_disaster['Year'] == 2004)]
disaster_2005 = filter_disaster.loc[(filter_disaster['Year'] == 2005)]
disaster_2006 = filter_disaster.loc[(filter_disaster['Year'] == 2006)]
disaster_2007 = filter_disaster.loc[(filter_disaster['Year'] == 2007)]
disaster_2008 = filter_disaster.loc[(filter_disaster['Year'] == 2008)]
disaster_2009 = filter_disaster.loc[(filter_disaster['Year'] == 2009)]
disaster_2010 = filter_disaster.loc[(filter_disaster['Year'] == 2010)]
disaster_2011 = filter_disaster.loc[(filter_disaster['Year'] == 2011)]
disaster_2012 = filter_disaster.loc[(filter_disaster['Year'] == 2012)]
disaster_2013 = filter_disaster.loc[(filter_disaster['Year'] == 2013)]
disaster_2014 = filter_disaster.loc[(filter_disaster['Year'] == 2014)]
disaster_2015 = filter_disaster.loc[(filter_disaster['Year'] == 2015)]
disaster_2016 = filter_disaster.loc[(filter_disaster['Year'] == 2016)]
disaster_2017 = filter_disaster.loc[(filter_disaster['Year'] == 2017)]
disaster_2018 = filter_disaster.loc[(filter_disaster['Year'] == 2018)]
disaster_2019 = filter_disaster.loc[(filter_disaster['Year'] == 2019)]
disaster_2020 = filter_disaster.loc[(filter_disaster['Year'] == 2020)]
disaster_2021 = filter_disaster.loc[(filter_disaster['Year'] == 2021)]
disaster_2022 = filter_disaster.loc[(filter_disaster['Year'] == 2022)]
# Out:
# 187

# %%
data1 = []
data2 = []

data1.append(disaster_2000[disaster_2000['Disaster Subgroup'] == 'Climatological']['Disaster Type'].value_counts().sum())
data1.append(disaster_2001[disaster_2001['Disaster Subgroup'] == 'Climatological']['Disaster Type'].value_counts().sum())
data1.append(disaster_2002[disaster_2002['Disaster Subgroup'] == 'Climatological']['Disaster Type'].value_counts().sum())
data1.append(disaster_2003[disaster_2003['Disaster Subgroup'] == 'Climatological']['Disaster Type'].value_counts().sum())
data1.append(disaster_2004[disaster_2004['Disaster Subgroup'] == 'Climatological']['Disaster Type'].value_counts().sum())
data1.append(disaster_2005[disaster_2005['Disaster Subgroup'] == 'Climatological']['Disaster Type'].value_counts().sum())
data1.append(disaster_2006[disaster_2006['Disaster Subgroup'] == 'Climatological']['Disaster Type'].value_counts().sum())
data1.append(disaster_2007[disaster_2007['Disaster Subgroup'] == 'Climatological']['Disaster Type'].value_counts().sum())
data1.append(disaster_2008[disaster_2008['Disaster Subgroup'] == 'Climatological']['Disaster Type'].value_counts().sum())
data1.append(disaster_2009[disaster_2009['Disaster Subgroup'] == 'Climatological']['Disaster Type'].value_counts().sum())
data1.append(disaster_2010[disaster_2010['Disaster Subgroup'] == 'Climatological']['Disaster Type'].value_counts().sum())
data1.append(disaster_2011[disaster_2011['Disaster Subgroup'] == 'Climatological']['Disaster Type'].value_counts().sum())
data1.append(disaster_2012[disaster_2012['Disaster Subgroup'] == 'Climatological']['Disaster Type'].value_counts().sum())
data1.append(disaster_2013[disaster_2013['Disaster Subgroup'] == 'Climatological']['Disaster Type'].value_counts().sum())
data1.append(disaster_2014[disaster_2014['Disaster Subgroup'] == 'Climatological']['Disaster Type'].value_counts().sum())
data1.append(disaster_2015[disaster_2015['Disaster Subgroup'] == 'Climatological']['Disaster Type'].value_counts().sum())
data1.append(disaster_2016[disaster_2016['Disaster Subgroup'] == 'Climatological']['Disaster Type'].value_counts().sum())
data1.append(disaster_2017[disaster_2017['Disaster Subgroup'] == 'Climatological']['Disaster Type'].value_counts().sum())
data1.append(disaster_2018[disaster_2018['Disaster Subgroup'] == 'Climatological']['Disaster Type'].value_counts().sum())
data1.append(disaster_2019[disaster_2019['Disaster Subgroup'] == 'Climatological']['Disaster Type'].value_counts().sum())
data1.append(disaster_2020[disaster_2020['Disaster Subgroup'] == 'Climatological']['Disaster Type'].value_counts().sum())
data1.append(disaster_2021[disaster_2021['Disaster Subgroup'] == 'Climatological']['Disaster Type'].value_counts().sum())
data1.append(disaster_2022[disaster_2022['Disaster Subgroup'] == 'Climatological']['Disaster Type'].value_counts().sum())

data2.append(disaster_2000[disaster_2000['Disaster Subgroup'] == 'Meteorological']['Disaster Type'].value_counts().sum())
data2.append(disaster_2001[disaster_2001['Disaster Subgroup'] == 'Meteorological']['Disaster Type'].value_counts().sum())
data2.append(disaster_2002[disaster_2002['Disaster Subgroup'] == 'Meteorological']['Disaster Type'].value_counts().sum())
data2.append(disaster_2003[disaster_2003['Disaster Subgroup'] == 'Meteorological']['Disaster Type'].value_counts().sum())
data2.append(disaster_2004[disaster_2004['Disaster Subgroup'] == 'Meteorological']['Disaster Type'].value_counts().sum())
data2.append(disaster_2005[disaster_2005['Disaster Subgroup'] == 'Meteorological']['Disaster Type'].value_counts().sum())
data2.append(disaster_2006[disaster_2006['Disaster Subgroup'] == 'Meteorological']['Disaster Type'].value_counts().sum())
data2.append(disaster_2007[disaster_2007['Disaster Subgroup'] == 'Meteorological']['Disaster Type'].value_counts().sum())
data2.append(disaster_2008[disaster_2008['Disaster Subgroup'] == 'Meteorological']['Disaster Type'].value_counts().sum())
data2.append(disaster_2009[disaster_2009['Disaster Subgroup'] == 'Meteorological']['Disaster Type'].value_counts().sum())
data2.append(disaster_2010[disaster_2010['Disaster Subgroup'] == 'Meteorological']['Disaster Type'].value_counts().sum())
data2.append(disaster_2011[disaster_2011['Disaster Subgroup'] == 'Meteorological']['Disaster Type'].value_counts().sum())
data2.append(disaster_2012[disaster_2012['Disaster Subgroup'] == 'Meteorological']['Disaster Type'].value_counts().sum())
data2.append(disaster_2013[disaster_2013['Disaster Subgroup'] == 'Meteorological']['Disaster Type'].value_counts().sum())
data2.append(disaster_2014[disaster_2014['Disaster Subgroup'] == 'Meteorological']['Disaster Type'].value_counts().sum())
data2.append(disaster_2015[disaster_2015['Disaster Subgroup'] == 'Meteorological']['Disaster Type'].value_counts().sum())
data2.append(disaster_2016[disaster_2016['Disaster Subgroup'] == 'Meteorological']['Disaster Type'].value_counts().sum())
data2.append(disaster_2017[disaster_2017['Disaster Subgroup'] == 'Meteorological']['Disaster Type'].value_counts().sum())
data2.append(disaster_2018[disaster_2018['Disaster Subgroup'] == 'Meteorological']['Disaster Type'].value_counts().sum())
data2.append(disaster_2019[disaster_2019['Disaster Subgroup'] == 'Meteorological']['Disaster Type'].value_counts().sum())
data2.append(disaster_2020[disaster_2020['Disaster Subgroup'] == 'Meteorological']['Disaster Type'].value_counts().sum())
data2.append(disaster_2021[disaster_2021['Disaster Subgroup'] == 'Meteorological']['Disaster Type'].value_counts().sum())
data2.append(disaster_2022[disaster_2022['Disaster Subgroup'] == 'Meteorological']['Disaster Type'].value_counts().sum())

# %%
print(data1)
print(data2)
# Out:
# [55, 36, 46, 28, 19, 33, 18, 29, 21, 27, 28, 24, 24, 19, 24, 40, 24, 27, 27, 29, 19, 39, 28]
# [132, 128, 138, 111, 140, 170, 90, 129, 128, 107, 122, 99, 143, 118, 116, 133, 98, 140, 123, 112, 133, 122, 102]

# %%
year = ['2000','2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020']
data = pd.DataFrame({'year': range(2000, 2023), 'Climatological': data1, 'Meterological': data2})

fig, ax = plt.subplots(figsize=(8,6))
sns.lineplot(x='year', y='value', hue='variable', data=pd.melt(data, ['year']), ax=ax)
ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
ax.set_xlabel('Year')
ax.set_ylabel('event')
ax.legend(fontsize=10, facecolor='white', edgecolor='black', fancybox=True, shadow=True, loc='center left', bbox_to_anchor=(1, 0.05))
plt.grid(alpha=0)
sns.despine()

# %%
disaster_2000 = disaster.loc[(disaster['Year'] == 2000)]
disaster_2001 = disaster.loc[(disaster['Year'] == 2001)]
disaster_2002 = disaster.loc[(disaster['Year'] == 2002)]
disaster_2003 = disaster.loc[(disaster['Year'] == 2003)]
disaster_2004 = disaster.loc[(disaster['Year'] == 2004)]
disaster_2005 = disaster.loc[(disaster['Year'] == 2005)]
disaster_2006 = disaster.loc[(disaster['Year'] == 2006)]
disaster_2007 = disaster.loc[(disaster['Year'] == 2007)]
disaster_2008 = disaster.loc[(disaster['Year'] == 2008)]
disaster_2009 = disaster.loc[(disaster['Year'] == 2009)]
disaster_2010 = disaster.loc[(disaster['Year'] == 2010)]
disaster_2011 = disaster.loc[(disaster['Year'] == 2011)]
disaster_2012 = disaster.loc[(disaster['Year'] == 2012)]
disaster_2013 = disaster.loc[(disaster['Year'] == 2013)]
disaster_2014 = disaster.loc[(disaster['Year'] == 2014)]
disaster_2015 = disaster.loc[(disaster['Year'] == 2015)]
disaster_2016 = disaster.loc[(disaster['Year'] == 2016)]
disaster_2017 = disaster.loc[(disaster['Year'] == 2017)]
disaster_2018 = disaster.loc[(disaster['Year'] == 2018)]
disaster_2019 = disaster.loc[(disaster['Year'] == 2019)]
disaster_2020 = disaster.loc[(disaster['Year'] == 2020)]
disaster_2021 = disaster.loc[(disaster['Year'] == 2021)]
disaster_2022 = disaster.loc[(disaster['Year'] == 2022)]

# %%
data3 = []

data3.append(disaster_2000['Disaster Type'].value_counts().sum())
data3.append(disaster_2001['Disaster Type'].value_counts().sum())
data3.append(disaster_2002['Disaster Type'].value_counts().sum())
data3.append(disaster_2003['Disaster Type'].value_counts().sum())
data3.append(disaster_2004['Disaster Type'].value_counts().sum())
data3.append(disaster_2005['Disaster Type'].value_counts().sum())
data3.append(disaster_2006['Disaster Type'].value_counts().sum())
data3.append(disaster_2007['Disaster Type'].value_counts().sum())
data3.append(disaster_2008['Disaster Type'].value_counts().sum())
data3.append(disaster_2009['Disaster Type'].value_counts().sum())
data3.append(disaster_2010['Disaster Type'].value_counts().sum())
data3.append(disaster_2011['Disaster Type'].value_counts().sum())
data3.append(disaster_2012['Disaster Type'].value_counts().sum())
data3.append(disaster_2013['Disaster Type'].value_counts().sum())
data3.append(disaster_2014['Disaster Type'].value_counts().sum())
data3.append(disaster_2015['Disaster Type'].value_counts().sum())
data3.append(disaster_2016['Disaster Type'].value_counts().sum())
data3.append(disaster_2017['Disaster Type'].value_counts().sum())
data3.append(disaster_2018['Disaster Type'].value_counts().sum())
data3.append(disaster_2019['Disaster Type'].value_counts().sum())
data3.append(disaster_2020['Disaster Type'].value_counts().sum())
data3.append(disaster_2021['Disaster Type'].value_counts().sum())
data3.append(disaster_2022['Disaster Type'].value_counts().sum())

data = pd.DataFrame({'year': range(2000, 2023), 'Disater':data3})

fig, ax = plt.subplots(figsize=(8,6))
sns.lineplot(x='year', y='value', hue='variable', data=pd.melt(data, ['year']), ax=ax)
ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
ax.set_xlabel('Year')
ax.set_ylabel('event')
ax.legend(fontsize=10, facecolor='white', edgecolor='black', fancybox=True, shadow=True, loc='center left', bbox_to_anchor=(1, 0.05))
plt.grid(alpha=0)
sns.despine()

# %%
print(data3)
# Out:
# [523, 446, 533, 392, 405, 497, 446, 448, 402, 384, 441, 356, 372, 353, 348, 398, 349, 371, 336, 441, 402, 439, 339]
