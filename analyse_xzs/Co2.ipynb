# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import matplotlib
matplotlib.rc("font",family='SimHei')
matplotlib.rcParams['axes.unicode_minus']=False

# %% [markdown]
# 数据来源：
# 二氧化碳排放量 世界银行网站

# %% [markdown]
# 数据处理：
# 利用pandas读入csv文件并进行预处理
# 删除无用字段

# %%
co2 = pd.read_csv("./data/API_EN.ATM.CO2E.KT_DS2_zh_csv_v2_5361673.csv")
co2 = co2.drop('Indicator Name',axis=1)
co2 = co2.drop('Indicator Code',axis=1)
co2
# Out:
#     Country Name Country Code  1960  1961  1962  1963  1964  1965  1966  1967  \
# 0            阿鲁巴          ABW   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1            NaN          AFE   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2            阿富汗          AFG   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3            NaN          AFW   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4            安哥拉          AGO   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..           ...          ...   ...   ...   ...   ...   ...   ...   ...   ...
# 261          科索沃          XKX   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 262        也门共和国          YEM   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 263           南非          ZAF   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 264          赞比亚          ZMB   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 265         津巴布韦          ZWE   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      ...           2013           2014           2015           2016  \
# 0    ...            NaN            NaN            NaN            NaN
# 1    ...  565430.012964  587699.992426  574029.994987  578510.015696
# 2    ...    5989.999771    4880.000114    5949.999809    5300.000191
# 3    ...  193299.997561  201680.001885  198410.002500  206030.001298
# 4    ...   26959.999084   29629.999161   31649.999619   29760.000229
# ..   ...            ...            ...            ...            ...
# 261  ...            NaN            NaN            NaN            NaN
# 262  ...   27829.999924   27430.000305   13550.000191   10850.000381
# 263  ...  436920.013428  447929.992676  424809.997559  425140.014648
# 264  ...    4239.999771    4690.000057    4960.000038    5320.000172
# 265  ...   12279.999733   12079.999924   12430.000305   11020.000458
#
#               2017           2018           2019  2020  2021  Unnamed: 66
# 0              NaN            NaN            NaN   NaN   NaN          NaN
# 1    587509.992346  590040.005282  603030.016154   NaN   NaN          NaN
# 2      4780.000210    6070.000172    6079.999924   NaN   NaN          NaN
# 3    204740.000457  211719.999298  220740.000024   NaN   NaN          NaN
# 4     24250.000000   23959.999084   25209.999084   NaN   NaN          NaN
# ..             ...            ...            ...   ...   ...          ...
# 261            NaN            NaN            NaN   NaN   NaN          NaN
# 262   10010.000229    9720.000267   11100.000381   NaN   NaN          NaN
# 263  435649.993896  434350.006104  439640.014648   NaN   NaN          NaN
# 264    6809.999943    7730.000019    6800.000191   NaN   NaN          NaN
# 265   10340.000153   12380.000114   11760.000229   NaN   NaN          NaN
#
# [266 rows x 65 columns]

# %%
co2[co2['Country Name'] == '中国']
# Out:
#    Country Name Country Code  1960  1961  1962  1963  1964  1965  1966  1967  \
# 40           中国          CHN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#     ...          2013          2014          2015          2016          2017  \
# 40  ...  9.984570e+06  1.000667e+07  9.861100e+06  9.874660e+06  1.009601e+07
#
#             2018          2019  2020  2021  Unnamed: 66
# 40  1.050293e+07  1.070722e+07   NaN   NaN          NaN
#
# [1 rows x 65 columns]

# %%
co2[co2['Country Name'] == '美国']
# Out:
#     Country Name Country Code  1960  1961  1962  1963  1964  1965  1966  1967  \
# 251           美国          USA   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      ...          2013          2014          2015       2016          2017  \
# 251  ...  5.092100e+06  5.107210e+06  4.990710e+06  4894500.0  4.819370e+06
#
#              2018          2019  2020  2021  Unnamed: 66
# 251  4.975310e+06  4.817720e+06   NaN   NaN          NaN
#
# [1 rows x 65 columns]

# %%
co2_China = co2[co2['Country Name'] == '中国'].iloc[0,32:66]
co2_China
# Out:
# 1990                 2173360.0
# 1991                 2302180.0
# 1992                 2418180.0
# 1993                 2645410.0
# 1994                 2767670.0
# 1995                 3088620.0
# 1996                 3070510.0
# 1997                 3134110.0
# 1998                 3236280.0
# 1999                 3153660.0
# 2000                 3346530.0
# 2001                 3529080.0
# 2002            3810060.058594
# 2003             4415910.15625
# 2004            5124819.824219
# 2005            5824629.882812
# 2006            6437470.214844
# 2007            6993180.175781
# 2008            7199600.097656
# 2009            7719069.824219
# 2010            8474919.921875
# 2011            9282549.804688
# 2012            9541870.117188
# 2013              9984570.3125
# 2014           10006669.921875
# 2015            9861099.609375
# 2016             9874660.15625
# 2017           10096009.765625
# 2018             10502929.6875
# 2019           10707219.726562
# 2020                       NaN
# 2021                       NaN
# Unnamed: 66                NaN
# Name: 40, dtype: object

# %%
co2_America = co2[co2['Country Name'] == '美国'].iloc[0,32:66]
co2_America
# Out:
# 1990                4844520.0
# 1991                4807500.0
# 1992                4879630.0
# 1993                4995210.0
# 1994                5066810.0
# 1995                5117040.0
# 1996                5273490.0
# 1997                5543350.0
# 1998                5590540.0
# 1999                5609020.0
# 2000                5775810.0
# 2001                5748260.0
# 2002           5593029.785156
# 2003           5658990.234375
# 2004           5738290.039062
# 2005           5753490.234375
# 2006           5653080.078125
# 2007           5736319.824219
# 2008           5558379.882812
# 2009           5156430.175781
# 2010           5392109.863281
# 2011           5173600.097656
# 2012           4956060.058594
# 2013           5092100.097656
# 2014           5107209.960938
# 2015           4990709.960938
# 2016                4894500.0
# 2017           4819370.117188
# 2018           4975310.058594
# 2019           4817720.214844
# 2020                      NaN
# 2021                      NaN
# Unnamed: 66               NaN
# Name: 251, dtype: object

# %%
data = pd.DataFrame({'year': co2_China.index,
                     '中国二氧化碳排放量': co2_China.values,
                     '美国二氧化碳排放量': co2_America.values
                     })
fig, ax = plt.subplots(figsize=(8,6))
sns.lineplot(x='year', y='value', hue='variable', data=pd.melt(data, ['year']), ax=ax)
ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
plt.title('中美二氧化碳排放量曲线图')
ax.set_xlabel('年份')
ax.set_ylabel('二氧化碳排放量')
ax.legend(fontsize=10, facecolor='white', edgecolor='black', fancybox=True, shadow=True, loc='center left', bbox_to_anchor=(1, 0.05))
plt.grid(alpha=0)
sns.despine()

plt.show()
