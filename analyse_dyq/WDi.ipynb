# %%
import pandas as pd
df = pd.read_csv("./data/country_economic/WDICountryOrRegion.csv")
df
# Out:
#     Country/Region Code                   Short Name  \
# 0                   ABW                        Aruba
# 1                   AFE  Africa Eastern and Southern
# 2                   AFG                  Afghanistan
# 3                   AFW   Africa Western and Central
# 4                   AGO                       Angola
# ..                  ...                          ...
# 260                 XKX                       Kosovo
# 261                 YEM                        Yemen
# 262                 ZAF                 South Africa
# 263                 ZMB                       Zambia
# 264                 ZWE                     Zimbabwe
#
#                       Table Name                     Long Name 2-alpha code  \
# 0                          Aruba                         Aruba           AW
# 1    Africa Eastern and Southern   Africa Eastern and Southern           ZH
# 2                    Afghanistan  Islamic State of Afghanistan           AF
# ...
